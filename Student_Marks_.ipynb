# %%
import pandas as pd
import numpy as np

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df1=pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ##Display top 3 of the dataset

# %%
df1.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# ##Check the Last 3 Rows of the Dataset

# %%
df1.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ##Find the Shape of Our Dataset

# %%
print("Number of Rows : ",df1.shape[0])
print("Number of columns : ",df1.shape[1])
df1.shape
# Out:
# Number of Rows :  7
# Number of columns :  3
# (7, 3)

# %% [markdown]
# ##Get Information About Our Dataset Like Total Number Rows,Total Number of Columns,Datatypes of Each Column And Memory

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# ##Check Null values in Data Set

# %%
df1.isnull().sum() #there is no missing values in the dataset
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# ##Get over all Statistics About the Dataframe

# %%
df1.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %% [markdown]
# ##find the unique values

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ##Find the Number of Unique values from the Gender column

# %%
df1['Gender'].nunique() #it prints how many unique values are there in the column
# Out:
# 2

# %% [markdown]
# ##Count of Unique values in Gender column

# %%
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df1['Gender'].count() #it will count all the values from the  Gender column
# Out:
# 7

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# ##total number of students having marks between 90 to 100

# %%
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df1[df1['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
len(df1[(df1['Marks']>=90)& (df1['Marks']<=100)])
# Out:
# 4

# %%
#between method
df1[df1['Marks'].between(90,100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
sum(df1['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# ##Find the Average of the columns

# %%
df1['Marks'].mean()
# Out:
# 92.14285714285714

# %%
#finding the min marks and min marks
df1['Marks'].min()
# Out:
# 83

# %%
df1["Marks"].max()
# Out:
# 99

# %% [markdown]
# ##Apply Method

# %%
def marks(x):
  return x//2

# %%
df1['Marks'].apply(marks)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
#Adding the new column
df1['Half_Marks']=df1['Marks'].apply(marks)
df1
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male          49
# 1   Aadhya     89  Female          44
# 2   Krisha     99  Female          49
# 3   Vedant     87    Male          43
# 4   Parshv     90    Male          45
# 5   Mittal     83  Female          41
# 6  Archana     99  Female          49

# %%
df1['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %% [markdown]
# #lenght of strings

# %%
df1['Name'].apply(len)
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %% [markdown]
# ##Map function

# %%
df1
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male          49
# 1   Aadhya     89  Female          44
# 2   Krisha     99  Female          49
# 3   Vedant     87    Male          43
# 4   Parshv     90    Male          45
# 5   Mittal     83  Female          41
# 6  Archana     99  Female          49

# %%
#converting the Male into 1 and female into 0
df1['Gender'].map({"Male":1,"Female":0})
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# Name: Gender, dtype: int64

# %% [markdown]
# ##Drop of the Column

# %%
df1.drop('Half_Marks',axis=1) #removing the half marks column
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ##print Name of the Columns

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'Half_Marks'], dtype='object')

# %% [markdown]
# ##sort the Dataframe As per the Marks column

# %%
df1
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male          49
# 1   Aadhya     89  Female          44
# 2   Krisha     99  Female          49
# 3   Vedant     87    Male          43
# 4   Parshv     90    Male          45
# 5   Mittal     83  Female          41
# 6  Archana     99  Female          49

# %%
df1.sort_values(by='Marks') #it will form in the ascending order
# Out:
#       Name  Marks  Gender  Half_Marks
# 5   Mittal     83  Female          41
# 3   Vedant     87    Male          43
# 1   Aadhya     89  Female          44
# 4   Parshv     90    Male          45
# 0  Priyang     98    Male          49
# 2   Krisha     99  Female          49
# 6  Archana     99  Female          49

# %%
df1.sort_values(by='Marks',ascending=False) #it will form in the descending order
# Out:
#       Name  Marks  Gender  Half_Marks
# 2   Krisha     99  Female          49
# 6  Archana     99  Female          49
# 0  Priyang     98    Male          49
# 4   Parshv     90    Male          45
# 1   Aadhya     89  Female          44
# 3   Vedant     87    Male          43
# 5   Mittal     83  Female          41

# %%
##sort the two columns

# %%
df1.sort_values(by=['Marks','Gender'],ascending=False)
# Out:
#       Name  Marks  Gender  Half_Marks
# 2   Krisha     99  Female          49
# 6  Archana     99  Female          49
# 0  Priyang     98    Male          49
# 4   Parshv     90    Male          45
# 1   Aadhya     89  Female          44
# 3   Vedant     87    Male          43
# 5   Mittal     83  Female          41

# %%
df1["Gender"]=='Female'
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# Name: Gender, dtype: bool
